# %%
# Stacked LSTM for international airline passengers problem with memory
import numpy
import matplotlib.pyplot as plt
import pandas as pd
import math
import datetime
import pylab as pl
from IPython import display
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

def create_time_series(df, period=5):
    for index, row in df.iterrows():
        print(datetime.datetime.fromtimestamp(index))
        print(index)
        print(row[0])
        print(row[1])
        print(numpy.mean(row))
        break

# %%
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
# load the dataset
dataframe = pd.read_csv('spread.csv', index_col=0, usecols=['timestamp', 'bid'], header=0, engine='python')
dataframe.index = pd.to_datetime(dataframe.index, unit='s')
dataframe = dataframe.resample('5Min').mean()
dataframe = dataframe.fillna(method='pad')
dataframe = dataframe[130:]
print(dataframe.head(5))

dataset = dataframe.values
#create_time_series(dataframe, period=5)
dataset = dataset.astype('float32')
dataframe.plot()
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
# Out:
#                              bid
# timestamp
# 2017-08-02 05:55:00  2745.150187
# 2017-08-02 06:00:00  2743.142738
# 2017-08-02 06:05:00  2741.633763
# 2017-08-02 06:10:00  2740.419867
# 2017-08-02 06:15:00  2736.558462

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.95)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(train[0])
# reshape into X=t and Y=t+1
look_back = 5
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)
# reshape input to be [samples, time steps, features]
print(trainX.shape)
print(trainX[0])
print(trainY[0])
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))
# Out:
# [ 0.15793896]
# (862, 5)
# [ 0.15793896  0.15446472  0.15185261  0.14975166  0.14306736]
# 0.148355

# %%
# create and fit the LSTM network
batch_size = 1
model = Sequential()
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True, return_sequences=True))
model.add(LSTM(4, batch_input_shape=(batch_size, look_back, 1), stateful=True))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
for i in range(100):
    model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
    model.reset_states()
    
    model_test = model
    
    # make predictions
    trainPredict = model_test.predict(trainX, batch_size=batch_size)
    model_test.reset_states()
    testPredict = model_test.predict(testX, batch_size=batch_size)
    # invert predictions
    trainPredict = scaler.inverse_transform(trainPredict)
    trainY_test = scaler.inverse_transform([trainY])
    testPredict = scaler.inverse_transform(testPredict)
    testY_test = scaler.inverse_transform([testY])
    
    # calculate root mean squared error
    trainScore = math.sqrt(mean_squared_error(trainY_test[0], trainPredict[:,0]))
    print('Train Score: %.2f RMSE' % (trainScore))
    testScore = math.sqrt(mean_squared_error(testY_test[0], testPredict[:,0]))
    print('Test Score: %.2f RMSE' % (testScore))
    
    # shift train predictions for plotting
    trainPredictPlot = numpy.empty_like(dataset)
    trainPredictPlot[:, :] = numpy.nan
    trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
    # shift test predictions for plotting
    testPredictPlot = numpy.empty_like(dataset)
    testPredictPlot[:, :] = numpy.nan
    testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict
    # plot baseline and predictions
    plt.plot(scaler.inverse_transform(dataset))
    plt.plot(trainPredictPlot)
    plt.plot(testPredictPlot)
    plt.show()
# Out:
# Epoch 1/1
# 4s - loss: 9.3536e-04
# Train Score: 259.59 RMSE
# Test Score: 54.73 RMSE
# Epoch 1/1
# 3s - loss: 0.0033
# Train Score: 301.32 RMSE
# Test Score: 31.97 RMSE
# Epoch 1/1
# 3s - loss: 0.0049
# Test Score: 37.01 RMSE
# Epoch 1/1
# 3s - loss: 2.6906e-04
# Train Score: 31.46 RMSE
# Test Score: 36.69 RMSE
# Epoch 1/1
# 3s - loss: 2.3247e-04
# Train Score: 30.05 RMSE
# Test Score: 36.84 RMSE
# Epoch 1/1
# 3s - loss: 2.3074e-04
# Train Score: 32.01 RMSE
# Test Score: 36.27 RMSE
# Epoch 1/1
# 3s - loss: 2.3044e-04
# Train Score: 34.24 RMSE
# Test Score: 36.02 RMSE
# Epoch 1/1
# 3s - loss: 2.2969e-04
# Train Score: 34.52 RMSE
# Test Score: 34.80 RMSE
# Epoch 1/1
# 3s - loss: 2.4519e-04
# Train Score: 42.55 RMSE
# Test Score: 32.89 RMSE
# Epoch 1/1
# 3s - loss: 2.2661e-04
# Train Score: 31.08 RMSE
# Test Score: 32.01 RMSE
# Epoch 1/1
# 3s - loss: 2.1672e-04
# Train Score: 28.34 RMSE
# Test Score: 32.21 RMSE
# Epoch 1/1
# 3s - loss: 2.1979e-04
# Train Score: 23.11 RMSE
# Test Score: 33.85 RMSE
# Epoch 1/1
# 3s - loss: 2.0974e-04
# Train Score: 31.45 RMSE
# Test Score: 32.97 RMSE
# Epoch 1/1
# 3s - loss: 2.0309e-04
# Train Score: 25.35 RMSE
# Test Score: 33.77 RMSE
# Epoch 1/1
# 3s - loss: 2.1075e-04
# Train Score: 33.03 RMSE
# Test Score: 33.22 RMSE
# Epoch 1/1
# 3s - loss: 2.0190e-04
# Train Score: 25.23 RMSE
# Test Score: 34.11 RMSE
# Epoch 1/1
# 3s - loss: 2.0470e-04
# Train Score: 36.73 RMSE
# Test Score: 29.41 RMSE
# Epoch 1/1
# 3s - loss: 2.1132e-04
# Train Score: 31.31 RMSE
# Test Score: 34.22 RMSE
# Epoch 1/1
# 3s - loss: 2.5093e-04
# Train Score: 39.49 RMSE
# Test Score: 27.98 RMSE
# Epoch 1/1
# 3s - loss: 2.3452e-04
# Train Score: 17.53 RMSE
# Test Score: 29.41 RMSE
# Epoch 1/1
# 3s - loss: 2.0316e-04
# Train Score: 22.37 RMSE
# Test Score: 28.12 RMSE
# Epoch 1/1
# 3s - loss: 1.8282e-04
# Train Score: 17.91 RMSE
# Test Score: 33.84 RMSE
# Epoch 1/1
# 3s - loss: 1.9003e-04
# Train Score: 34.12 RMSE
# Test Score: 27.94 RMSE
# Epoch 1/1
# 3s - loss: 1.9280e-04
# Train Score: 20.94 RMSE
# Test Score: 35.22 RMSE
# Epoch 1/1
# 3s - loss: 1.8606e-04
# Train Score: 37.12 RMSE
# Test Score: 27.83 RMSE
# Epoch 1/1
# 3s - loss: 2.0850e-04
# Train Score: 19.28 RMSE
# Test Score: 30.36 RMSE
# Epoch 1/1
# 3s - loss: 2.0495e-04
# Train Score: 28.70 RMSE
# Test Score: 27.48 RMSE
# Epoch 1/1
# 3s - loss: 1.9255e-04
# Train Score: 25.93 RMSE
# Test Score: 25.22 RMSE
# Epoch 1/1
# 3s - loss: 1.8979e-04
# Train Score: 16.71 RMSE
# Test Score: 35.68 RMSE
# Epoch 1/1
# 3s - loss: 1.8974e-04
# Train Score: 33.11 RMSE
# Test Score: 26.96 RMSE
# Epoch 1/1
# 3s - loss: 1.8331e-04
# Train Score: 20.97 RMSE
# Test Score: 33.13 RMSE
# Epoch 1/1
# 3s - loss: 2.0896e-04
# Train Score: 37.23 RMSE
# Test Score: 26.90 RMSE
# Epoch 1/1
# 3s - loss: 1.9418e-04
# Train Score: 40.10 RMSE
# Test Score: 33.61 RMSE
# Epoch 1/1
# 3s - loss: 2.5031e-04
# Train Score: 28.77 RMSE
# Test Score: 32.12 RMSE
# Epoch 1/1
# 3s - loss: 1.8322e-04
# Train Score: 25.21 RMSE
# Test Score: 27.74 RMSE
# Epoch 1/1
# 3s - loss: 1.5866e-04
# Train Score: 10.82 RMSE
# Test Score: 36.61 RMSE
# Epoch 1/1
# 3s - loss: 1.6743e-04
# Train Score: 32.74 RMSE
# Test Score: 30.32 RMSE
# Epoch 1/1
# 3s - loss: 1.8177e-04
# Train Score: 33.01 RMSE
# Test Score: 25.71 RMSE
# Epoch 1/1
# 3s - loss: 1.7769e-04
# Train Score: 14.75 RMSE
# Test Score: 35.69 RMSE
# Epoch 1/1
# 3s - loss: 1.9615e-04
# Train Score: 33.48 RMSE
# Test Score: 33.44 RMSE
# Epoch 1/1
# 3s - loss: 1.7419e-04
# Train Score: 26.24 RMSE
# Test Score: 36.54 RMSE
# Epoch 1/1
# 3s - loss: 1.6490e-04
# Train Score: 28.39 RMSE
# Test Score: 34.87 RMSE
# Epoch 1/1
# 3s - loss: 1.8678e-04
# Train Score: 29.34 RMSE
# Test Score: 27.38 RMSE
# Epoch 1/1
# 3s - loss: 1.7741e-04
# Train Score: 17.71 RMSE
# Test Score: 31.96 RMSE
# Epoch 1/1
# 3s - loss: 1.7634e-04
# Train Score: 31.73 RMSE
# Test Score: 26.50 RMSE
# Epoch 1/1
# 3s - loss: 1.5651e-04
# Train Score: 11.70 RMSE
# Test Score: 39.64 RMSE
# Epoch 1/1
# 3s - loss: 1.7451e-04
# Train Score: 37.98 RMSE
# Test Score: 30.21 RMSE
# Epoch 1/1
# 3s - loss: 1.7844e-04
# Train Score: 35.73 RMSE
# Test Score: 25.49 RMSE
# Epoch 1/1
# 3s - loss: 1.7189e-04
# Train Score: 11.54 RMSE
# Test Score: 39.82 RMSE
# Epoch 1/1
# 3s - loss: 1.7068e-04
# Train Score: 32.98 RMSE
# Test Score: 26.32 RMSE
# Epoch 1/1
# 3s - loss: 1.5073e-04
# Train Score: 13.69 RMSE
# Test Score: 39.38 RMSE
