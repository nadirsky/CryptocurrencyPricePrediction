# %%
import krakenex
import datetime
import calendar
import pandas as pd
import time
import os.path
import numpy as np

# %matplotlib inline

# %%
k = krakenex.API()
k.load_key('kraken.key')

# %%
if os.path.isfile('trades.csv'):
    df_trades = pd.read_csv('trades.csv', index_col=0, header=0)
else:
    df_trades = pd.DataFrame(columns=['timestamp','volume','price','buysell','marketlimit','misc'])

#print(df_trades.dtypes)
    
if os.path.isfile('last.txt'):
    file = open('last.txt', 'r') 
    last = int(file.read())
    file.close()
else:
    last = 0

while True:
#for i in range(1):
    try:
        trades = k.query_public('Trades', {'pair': 'XXBTZUSD', 'since': last})
    except:
        time.sleep(10)
        pass
    else:
        if not trades['error']:
            last = trades['result']['last']
            btc_trades = np.array(trades['result']['XXBTZUSD'])
            btc_trades[:,0], btc_trades[:,2] = btc_trades[:,2], btc_trades[:,0].copy()
            #print(btc_trades)
            df_temp = pd.DataFrame(data=btc_trades, columns=['timestamp','volume','price','buysell','marketlimit','misc'])
            df_temp[['timestamp','volume','price']] = df_temp[['timestamp','volume','price']].astype('float64')
            #print(df_temp.head(1))
            print(df_temp.tail(1))
            #print(df_temp.dtypes)

            df_trades = pd.concat([df_trades,df_temp], ignore_index=True).drop_duplicates().sort_values('timestamp').reset_index(drop=True)  

            df_trades.to_csv('trades.csv')
            file = open('last.txt', 'w')
            file.write(last)
            file.close()

            time.sleep(40)
        else:
            print(trades['error'])
            time.sleep(10)

#print(df_trades)

#df_spread.plot(x='timestamp', y=['price','volume'])
# Out:
# /home/nadirsky/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:395: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#       timestamp  volume     price buysell marketlimit misc
# 4  1.502114e+09   0.153  3402.001       s           l
#       timestamp   volume     price buysell marketlimit misc
# 3  1.502114e+09  0.03313  3401.798       b           l
#        timestamp    volume     price buysell marketlimit misc
# 20  1.502114e+09  0.000977  3400.204       b           l
#       timestamp    volume   price buysell marketlimit misc
# 9  1.502115e+09  0.965031  3402.0       b           l
#        timestamp    volume   price buysell marketlimit misc
# 21  1.502115e+09  8.352934  3400.0       s           l
#        timestamp  volume   price buysell marketlimit misc
# 15  1.502115e+09   1.628  3400.0       s           l
#        timestamp  volume    price buysell marketlimit misc
# 26  1.502115e+09  0.0147  3395.21       s           l
#        timestamp    volume   price buysell marketlimit misc
# 34  1.502115e+09  0.088566  3390.0       b           l
#        timestamp   volume    price buysell marketlimit misc
# 35  1.502115e+09  0.12983  3383.01       s           m
#        timestamp  volume    price buysell marketlimit misc
# 19  1.502115e+09    0.08  3380.89       s           l
#        timestamp  volume   price buysell marketlimit misc
# 18  1.502115e+09  0.0169  3380.0       b           l
#        timestamp    volume    price buysell marketlimit misc
# 23  1.502115e+09  0.004313  3376.45       s           l
#        timestamp  volume     price buysell marketlimit misc
# 35  1.502115e+09  0.0163  3376.476       s           l
#        timestamp    volume    price buysell marketlimit misc
# 60  1.502115e+09  0.008626  3383.01       s           m
#        timestamp    volume   price buysell marketlimit misc
# 22  1.502115e+09  1.249185  3380.0       s           m
#        timestamp    volume     price buysell marketlimit misc
# 22  1.502115e+09  0.111809  3384.909       s           l
#        timestamp  volume   price buysell marketlimit misc
# 47  1.502115e+09  0.0124  3387.9       s           l
#        timestamp  volume    price buysell marketlimit misc
# 36  1.502115e+09  0.0526  3384.91       s           l
#        timestamp  volume   price buysell marketlimit misc
# 17  1.502115e+09  0.0163  3387.9       b           l
#        timestamp   volume     price buysell marketlimit misc
# 31  1.502116e+09  0.25354  3385.641       s           m
#       timestamp  volume     price buysell marketlimit misc
# 3  1.502116e+09  0.3249  3385.641       s           l
#        timestamp  volume     price buysell marketlimit misc
# 37  1.502116e+09     0.1  3385.641       s           l
#        timestamp   volume     price buysell marketlimit misc
# 28  1.502116e+09  0.00816  3384.426       b           l
#        timestamp  volume   price buysell marketlimit misc
# 37  1.502116e+09  0.0163  3375.0       s           l
#        timestamp  volume     price buysell marketlimit misc
# 34  1.502116e+09   1.337  3350.001       s           m
#        timestamp  volume   price buysell marketlimit misc
# 36  1.502116e+09    0.01  3356.0       b           m
#        timestamp  volume     price buysell marketlimit misc
# 14  1.502116e+09   0.035  3353.351       s           m
#        timestamp    volume   price buysell marketlimit misc
# 32  1.502116e+09  0.222016  3357.0       s           l
#        timestamp    volume     price buysell marketlimit misc
# 24  1.502116e+09  0.086387  3360.356       s           l
#        timestamp  volume     price buysell marketlimit misc
# 31  1.502116e+09   0.162  3371.002       b           m
#        timestamp    volume     price buysell marketlimit misc
# 22  1.502116e+09  0.177989  3371.001       b           l
#       timestamp    volume     price buysell marketlimit misc
# 8  1.502116e+09  0.072409  3370.999       b           m
#        timestamp    volume     price buysell marketlimit misc
# 17  1.502116e+09  0.057289  3374.691       b           l
#        timestamp    volume     price buysell marketlimit misc
# 12  1.502116e+09  0.172289  3374.998       s           l
#        timestamp    volume     price buysell marketlimit misc
# 14  1.502116e+09  0.319154  3374.996       s           l
#        timestamp  volume     price buysell marketlimit misc
# 11  1.502116e+09  0.0221  3374.997       s           l
#       timestamp  volume     price buysell marketlimit misc
# 9  1.502116e+09  0.0103  3374.996       s           l
#        timestamp  volume     price buysell marketlimit misc
# 33  1.502117e+09  0.0253  3374.997       s           l
#        timestamp  volume   price buysell marketlimit misc
# 14  1.502117e+09  0.0153  3375.0       b           l
#        timestamp    volume     price buysell marketlimit misc
# 18  1.502117e+09  0.567672  3374.998       b           l
#        timestamp    volume   price buysell marketlimit misc
# 22  1.502117e+09  0.459028  3375.0       s           l
#        timestamp    volume   price buysell marketlimit misc
# 20  1.502117e+09  1.305972  3375.0       s           l
#        timestamp    volume   price buysell marketlimit misc
# 10  1.502117e+09  0.000367  3375.0       s           l
#        timestamp    volume   price buysell marketlimit misc
# 11  1.502117e+09  0.000196  3375.0       b           l
#        timestamp  volume   price buysell marketlimit misc
# 18  1.502117e+09   0.303  3383.0       s           l
#       timestamp  volume     price buysell marketlimit misc
# 6  1.502117e+09    0.09  3384.007       b           m
#       timestamp    volume   price buysell marketlimit misc
# 3  1.502117e+09  0.230468  3383.0       s           l
#        timestamp  volume   price buysell marketlimit misc
# 22  1.502117e+09  0.0593  3375.0       b           l
#        timestamp  volume     price buysell marketlimit misc
# 11  1.502117e+09     0.5  3377.258       s           m
#        timestamp  volume    price buysell marketlimit misc
# 22  1.502117e+09   0.088  3385.25       b           m
#        timestamp    volume   price buysell marketlimit misc
# 28  1.502117e+09  0.000605  3387.9       b           m
#        timestamp  volume     price buysell marketlimit misc
# 30  1.502117e+09     0.1  3384.895       b           m
#       timestamp  volume     price buysell marketlimit misc
# 7  1.502117e+09  0.8139  3379.901       s           l
#        timestamp  volume     price buysell marketlimit misc
# 14  1.502118e+09  0.0104  3378.995       b           l
#       timestamp  volume   price buysell marketlimit misc
# 5  1.502118e+09    0.05  3378.2       s           l
#        timestamp    volume   price buysell marketlimit misc
# 22  1.502118e+09  1.615723  3384.8       b           m
#        timestamp    volume     price buysell marketlimit misc
# 16  1.502118e+09  0.123968  3379.101       s           l
#       timestamp   volume   price buysell marketlimit misc
# 8  1.502118e+09  4.76819  3380.0       b           l
#       timestamp   volume   price buysell marketlimit misc
# 8  1.502118e+09  0.13818  3380.0       b           l
#        timestamp  volume     price buysell marketlimit misc
# 11  1.502118e+09     0.1  3384.699       b           m
#        timestamp   volume   price buysell marketlimit misc
# 14  1.502118e+09  0.23256  3385.0       s           l
#        timestamp    volume   price buysell marketlimit misc
# 23  1.502118e+09  0.164914  3385.0       b           l
#       timestamp    volume     price buysell marketlimit misc
# 8  1.502118e+09  0.034076  3387.993       b           m
#        timestamp  volume   price buysell marketlimit misc
# 35  1.502118e+09  0.0655  3388.0       s           l
#        timestamp   volume   price buysell marketlimit misc
# 57  1.502118e+09  0.13818  3399.0       b           m
#       timestamp    volume     price buysell marketlimit misc
# 8  1.502118e+09  0.232779  3389.359       s           l
#       timestamp    volume    price buysell marketlimit misc
# 8  1.502118e+09  0.014885  3389.35       b           l
#        timestamp    volume     price buysell marketlimit misc
# 10  1.502118e+09  0.022521  3389.359       b           l
#        timestamp    volume     price buysell marketlimit misc
# 14  1.502118e+09  0.059124  3389.099       b           l
#        timestamp  volume     price buysell marketlimit misc
# 18  1.502118e+09  0.0806  3386.193       b           l
#       timestamp    volume     price buysell marketlimit misc
# 8  1.502118e+09  0.007718  3388.699       s           l
#        timestamp    volume     price buysell marketlimit misc
# 14  1.502118e+09  0.563733  3391.773       s           l
#       timestamp    volume   price buysell marketlimit misc
# 6  1.502119e+09  3.839568  3392.5       b           l
#       timestamp    volume   price buysell marketlimit misc
# 5  1.502119e+09  0.032549  3392.5       b           m
#        timestamp  volume   price buysell marketlimit misc
# 53  1.502119e+09  0.0501  3387.0       s           l
#        timestamp    volume    price buysell marketlimit misc
# 19  1.502119e+09  0.380121  3384.69       s           l
#        timestamp  volume   price buysell marketlimit misc
# 17  1.502119e+09  0.0213  3384.1       s           l
#        timestamp    volume     price buysell marketlimit misc
# 11  1.502119e+09  0.034611  3386.998       b           l
#        timestamp  volume     price buysell marketlimit misc
# 10  1.502119e+09     0.3  3383.999       s           m
#       timestamp    volume     price buysell marketlimit misc
# 5  1.502119e+09  3.271058  3384.099       s           l
#       timestamp    volume     price buysell marketlimit misc
# 9  1.502119e+09  0.115072  3383.896       s           l
#       timestamp   volume     price buysell marketlimit misc
# 7  1.502119e+09  0.00054  3383.896       s           m
#       timestamp  volume     price buysell marketlimit misc
# 5  1.502119e+09  0.2965  3381.536       s           l
#       timestamp    volume   price buysell marketlimit misc
# 0  1.502119e+09  0.077864  3379.0       s           l
#       timestamp    volume   price buysell marketlimit misc
# 9  1.502119e+09  0.003975  3377.3       s           m
#       timestamp   volume   price buysell marketlimit misc
# 9  1.502119e+09  0.02594  3375.9       s           l
#       timestamp    volume     price buysell marketlimit misc
# 5  1.502119e+09  0.120089  3377.299       b           l
#       timestamp    volume   price buysell marketlimit misc
# 7  1.502119e+09  1.912662  3383.7       b           m
#        timestamp    volume     price buysell marketlimit misc
# 17  1.502119e+09  0.515749  3371.041       s           m
#       timestamp    volume     price buysell marketlimit misc
# 3  1.502119e+09  2.966992  3371.041       s           l
#       timestamp  volume     price buysell marketlimit misc
# 7  1.502119e+09     0.1  3383.201       s           l
#       timestamp  volume     price buysell marketlimit misc
# 3  1.502120e+09     0.2  3384.998       b           m
#       timestamp    volume   price buysell marketlimit misc
# 3  1.502120e+09  1.925107  3383.3       s           l
#       timestamp   volume     price buysell marketlimit misc
# 6  1.502120e+09  0.00797  3384.797       b           m
